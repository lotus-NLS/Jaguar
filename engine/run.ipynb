# %%
# %reload_ext autoreload
from engine import LotusEngine

# %%
the_engine = LotusEngine(use_local_credentials=True)
# Out:
# [2025-01-07 08:01:19]: Completed setup for all Settings

# %%
# %autoreload 2
the_engine.request_terminal()
# Out:
# [2025-01-07 08:01:19]: Lotus started
#  * Serving Flask app 'engine.l0_engine.engine'
#  * Debug mode: off
# Address already in use
# Port 5000 is in use by another program. Either identify and stop that program, or start the server with a different port.
# [2025-01-07 08:01:20]: Creating generation request
# [2025-01-07 08:01:21]: Received generation response. Currently at 622 tokens
# GOTO:
# Callmap = {0: <engine.l3_aos.tools.input.ToolCall object at 0x726e19704a10>}
# Processsing chunk
# Tool call zero json str =
# Callmap = {0: <engine.l3_aos.tools.input.ToolCall object at 0x726e1967f310>}
# Processsing chunk
# Tool call zero json str = {}
# Callmap = {}
# Processsing chunk
# Tool call zero json str = {}
# [2025-01-07 08:01:21]: [START]: Starting "open_Terminal" with args {}
# [2025-01-07 08:01:21]: [INFO]: Running tool "open_Terminal"
