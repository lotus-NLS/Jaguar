# %%
# %reload_ext autoreload
from engine import LotusEngine
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 2
#       1 get_ipython().run_line_magic('reload_ext', 'autoreload')
# ----> 2 from engine import LotusEngine
#
# File ~/lotus/engine/__init__.py:1
# ----> 1 from .l0_engine import LotusEngine
#
# File ~/lotus/engine/l0_engine/__init__.py:1
# ----> 1 from .engine import LotusEngine
#
# File ~/lotus/engine/l0_engine/engine.py:10
#       7 from flask import Flask
#       9 from api import Entry
# ---> 10 from engine.l1_agents import Agent, Task
#      11 from engine.l2_models import Context
#      12 from engine.l2_models import OpenAIModel
#
# File ~/lotus/engine/l1_agents/__init__.py:1
# ----> 1 from .agent import *
#       2 from .protocol import *
#
# File ~/lotus/engine/l1_agents/agent/__init__.py:1
# ----> 1 from .agent import Agent
#
# File ~/lotus/engine/l1_agents/agent/agent.py:8
#       5 from func_timeout import FunctionTimedOut
#       7 from api import Entry, TextPipe
# ----> 8 from engine.l1_agents.protocol import Identity, Task
#       9 from engine.l2_models import Context, Generation
#      10 from engine.l2_models.llm import LLM
#
# File ~/lotus/engine/l1_agents/protocol/__init__.py:2
#       1 from .identity import Identity, Core
# ----> 2 from .task import Task, TaskQueue
#
# File ~/lotus/engine/l1_agents/protocol/task.py:7
#       4 from typing import Optional
#       6 from api import Entry
# ----> 7 from engine.l2_models import Options, CallOptions
#      10 class Task:
#      11     def __init__(self, new_entries : list[Entry] = None, required_tool_name : Optional[str] = None):
#
# File ~/lotus/engine/l2_models/__init__.py:1
# ----> 1 from .providers import *
#       2 from .generation import *
#
# File ~/lotus/engine/l2_models/providers/__init__.py:1
# ----> 1 from .openai import OpenAIModel
#
# File ~/lotus/engine/l2_models/providers/openai.py:12
#      10 from api import Entry, APIType
#      11 from engine.l2_models.generation import Generation, Chunk, Options
# ---> 12 from engine.l2_models import Context
#      13 from engine.l2_models.llm import LLM
#      14 from engine.l3_aos.tools import ToolCall
#
# ImportError: cannot import name 'Context' from partially initialized module 'engine.l2_models' (most likely due to a circular import) (/home/daniel/lotus/engine/l2_models/__init__.py)

# %%
the_engine = LotusEngine(use_local_credentials=True)

# %%
# %autoreload 2
the_engine.request_terminal()
