# %%
# %load_ext autoreload
from engine import LotusEngine

# %%
# %autoreload 2
the_engine = LotusEngine(use_local_credentials=True)
# Out:
# [2025-01-07 07:30:07]: Completed setup for all Settings
# [2025-01-07 07:30:07]: Lotus started
#  * Serving Flask app 'engine.l0_engine.engine'
#  * Debug mode: off
# Address already in use
# Port 5000 is in use by another program. Either identify and stop that program, or start the server with a different port.
# [2025-01-07 07:30:08]: Creating generation request
# [2025-01-07 07:30:09]: Received generation response. Currently at 622 tokens
# GOTO:
# [2025-01-07 07:30:09]: [FAILED]: Toolopen_Terminal failed: Empty json string

# %%
the_engine.request_terminal()
# Out:
# [2025-01-07 07:30:31]: Lotus started
#  * Serving Flask app 'engine.l0_engine.engine'
#  * Debug mode: off
# Address already in use
# Port 5000 is in use by another program. Either identify and stop that program, or start the server with a different port.
# [2025-01-07 07:30:32]: Creating generation request
# [2025-01-07 07:30:34]: Received generation response. Currently at 726 tokens
# GOTO:
# [2025-01-07 07:30:34]: [FAILED]: Toolopen_Terminal failed: Empty json string
